# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn

# %%
#transforming
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

#dimensionality reduction
from sklearn.decomposition import PCA

#resampling (need to use imblearn pipeline)
import imblearn
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline


#performance measures
from sklearn.metrics import fbeta_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score, make_scorer


#ML models
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
full_frame = pd.read_csv("/Users/FelixHoffmann/Desktop/GreenLeaders/shared datasets/Final_Training_Data_65515.csv",index_col=0)

# %%
#function to create 120 pipelines for each ML Model it is applied to

#5 resampling options
resampling=[('None'),
            ('Rand_Over',('over', RandomOverSampler())),
            ('Rand_Under',('under', RandomUnderSampler())),
            ('SMOTE',('over', SMOTE())),
            ('SMOTE_Under',('over',SMOTE()),('under',RandomUnderSampler()))]

#6 transformation options
transformations=[('None'),
                ('Yeo_Johnson',('t1', PowerTransformer())),
                ('Box_Cox',('t1', MinMaxScaler(feature_range=(1, 2))),('t2', PowerTransformer(method='box-cox'))),
                ('MinMax',('t1', MinMaxScaler())),
                ('Standardize',('t1', StandardScaler())),
                ('Robust_Scaler',('t1', RobustScaler()))]

#4 dimensionality reduction options
dim_reductions=[('None'),
                ('PCA4',('pca',PCA(n_components=4))),
                ('PCA8',('pca',PCA(n_components=8))),
                ('PCA17',('pca',PCA(n_components=17)))]


def get_mixed_pipelines(model):

    pipelines = list()

    #for each dimensionality reduction
    for lijn in dim_reductions:

        #for each resampling technique
        for line in resampling:    

            #for each transformation
            for zeile in transformations:
                
                if lijn == 'None':
            
                    if line == 'None':
                        if zeile == 'None':
                            pipelines.append((f"{zeile}_{line}_{lijn}", imblearn.pipeline.Pipeline([('m',model)])))
                        elif len(zeile)<3:
                            pipelines.append((f"{zeile[0]}_{line}_{lijn}", imblearn.pipeline.Pipeline([zeile[1],('m',model)])))
                        else: 
                            pipelines.append((f"{zeile[0]}_{line}_{lijn}", imblearn.pipeline.Pipeline([zeile[1],zeile[2],('m',model)])))


                    elif len(line)<3:
                        if zeile == 'None':
                            pipelines.append((f"{zeile}_{line[0]}_{lijn}", imblearn.pipeline.Pipeline([line[1],('m',model)])))
                        elif len(zeile)<3:
                            pipelines.append((f"{zeile[0]}_{line[0]}_{lijn}", imblearn.pipeline.Pipeline([zeile[1],line[1],('m',model)])))
                        else: 
                            pipelines.append((f"{zeile[0]}_{line[0]}_{lijn}", imblearn.pipeline.Pipeline([zeile[1],zeile[2],line[1],('m',model)])))

                    else:
                        if zeile == 'None':
                            pipelines.append((f"{zeile}_{line[0]}_{lijn}", imblearn.pipeline.Pipeline([line[1],line[2],('m',model)])))
                        elif len(zeile)<3:
                            pipelines.append((f"{zeile[0]}_{line[0]}_{lijn}", imblearn.pipeline.Pipeline([zeile[1],line[1],line[2],('m',model)])))
                        else:
                            pipelines.append((f"{zeile[0]}_{line[0]}_{lijn}", imblearn.pipeline.Pipeline([zeile[1],zeile[2],line[1],line[2],('m',model)])))

                else: 
                    if line == 'None':
                        if zeile == 'None':
                            pipelines.append((f"{zeile}_{lijn[0]}_{line}", imblearn.pipeline.Pipeline([lijn[1],('m',model)])))
                        elif len(zeile)<3:
                            pipelines.append((f"{zeile[0]}_{lijn[0]}_{line}", imblearn.pipeline.Pipeline([zeile[1],lijn[1],('m',model)])))
                        else: 
                            pipelines.append((f"{zeile[0]}_{lijn[0]}_{line}", imblearn.pipeline.Pipeline([zeile[1],zeile[2],lijn[1],('m',model)])))

                    elif len(line)<3:
                        if zeile == 'None':
                            pipelines.append((f"{zeile}_{lijn[0]}_{line[0]}", imblearn.pipeline.Pipeline([lijn[1],line[1],('m',model)])))
                        elif len(zeile)<3:
                            pipelines.append((f"{zeile[0]}_{lijn[0]}_{line[0]}", imblearn.pipeline.Pipeline([zeile[1],lijn[1],line[1],('m',model)])))
                        else: 
                            pipelines.append((f"{zeile[0]}_{lijn[0]}_{line[0]}", imblearn.pipeline.Pipeline([zeile[1],zeile[2],lijn[1],line[1],('m',model)])))

                    else:
                        if zeile == 'None':
                            pipelines.append((f"{zeile}_{lijn[0]}_{line[0]}", imblearn.pipeline.Pipeline([lijn[1],line[1],line[2],('m',model)])))
                        elif len(zeile)<3:
                            pipelines.append((f"{zeile[0]}_{lijn[0]}_{line[0]}", imblearn.pipeline.Pipeline([zeile[1],lijn[1],line[1],line[2],('m',model)])))
                        else:
                            pipelines.append((f"{zeile[0]}_{lijn[0]}_{line[0]}", imblearn.pipeline.Pipeline([zeile[1],zeile[2],lijn[1],line[1],line[2],('m',model)])))
                            
                            
    return pipelines

# %%
#example: Get 120 pipelines for LDA:
get_mixed_pipelines(LinearDiscriminantAnalysis())
# Out:
# [('None_None_None', Pipeline(steps=[('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_None_None', Pipeline(steps=[('t1', PowerTransformer()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_None_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_None_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_None_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_None_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('m', LinearDiscriminantAnalysis())])),
#  ('None_Rand_Over_None', Pipeline(steps=[('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_Rand_Over_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_Rand_Over_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_Rand_Over_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_Rand_Over_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_Rand_Over_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_Rand_Under_None', Pipeline(steps=[('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_Rand_Under_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_Rand_Under_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_Rand_Under_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_Rand_Under_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_Rand_Under_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_SMOTE_None',
#   Pipeline(steps=[('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_SMOTE_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_SMOTE_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_SMOTE_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_SMOTE_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_SMOTE_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_SMOTE_Under_None',
#   Pipeline(steps=[('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_SMOTE_Under_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_SMOTE_Under_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_SMOTE_Under_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_SMOTE_Under_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_SMOTE_Under_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA4_None', Pipeline(steps=[('pca', PCA(n_components=4)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA4_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=4)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA4_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=4)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA4_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=4)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA4_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=4)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA4_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=4)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA4_Rand_Over',
#   Pipeline(steps=[('pca', PCA(n_components=4)), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA4_Rand_Over',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=4)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA4_Rand_Over',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=4)), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA4_Rand_Over',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=4)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA4_Rand_Over',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=4)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA4_Rand_Over',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=4)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA4_Rand_Under',
#   Pipeline(steps=[('pca', PCA(n_components=4)), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA4_Rand_Under',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=4)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA4_Rand_Under',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=4)), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA4_Rand_Under',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=4)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA4_Rand_Under',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=4)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA4_Rand_Under',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=4)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA4_SMOTE',
#   Pipeline(steps=[('pca', PCA(n_components=4)), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA4_SMOTE',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA4_SMOTE',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=4)), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA4_SMOTE',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA4_SMOTE',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA4_SMOTE',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA4_SMOTE_Under',
#   Pipeline(steps=[('pca', PCA(n_components=4)), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA4_SMOTE_Under',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA4_SMOTE_Under',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=4)), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA4_SMOTE_Under',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA4_SMOTE_Under',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA4_SMOTE_Under',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=4)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA8_None', Pipeline(steps=[('pca', PCA(n_components=8)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA8_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=8)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA8_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=8)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA8_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=8)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA8_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=8)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA8_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=8)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA8_Rand_Over',
#   Pipeline(steps=[('pca', PCA(n_components=8)), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA8_Rand_Over',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=8)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA8_Rand_Over',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=8)), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA8_Rand_Over',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=8)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA8_Rand_Over',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=8)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA8_Rand_Over',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=8)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA8_Rand_Under',
#   Pipeline(steps=[('pca', PCA(n_components=8)), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA8_Rand_Under',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=8)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA8_Rand_Under',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=8)), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA8_Rand_Under',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=8)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA8_Rand_Under',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=8)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA8_Rand_Under',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=8)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA8_SMOTE',
#   Pipeline(steps=[('pca', PCA(n_components=8)), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA8_SMOTE',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA8_SMOTE',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=8)), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA8_SMOTE',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA8_SMOTE',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA8_SMOTE',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA8_SMOTE_Under',
#   Pipeline(steps=[('pca', PCA(n_components=8)), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA8_SMOTE_Under',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA8_SMOTE_Under',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=8)), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA8_SMOTE_Under',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA8_SMOTE_Under',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA8_SMOTE_Under',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=8)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA17_None', Pipeline(steps=[('pca', PCA(n_components=17)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA17_None',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=17)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA17_None',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=17)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA17_None',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=17)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA17_None',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=17)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA17_None',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=17)),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA17_Rand_Over',
#   Pipeline(steps=[('pca', PCA(n_components=17)), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA17_Rand_Over',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=17)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA17_Rand_Over',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=17)), ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA17_Rand_Over',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=17)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA17_Rand_Over',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=17)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA17_Rand_Over',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=17)),
#                   ('over', RandomOverSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA17_Rand_Under',
#   Pipeline(steps=[('pca', PCA(n_components=17)), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA17_Rand_Under',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=17)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA17_Rand_Under',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=17)), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA17_Rand_Under',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=17)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA17_Rand_Under',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=17)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA17_Rand_Under',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=17)),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA17_SMOTE',
#   Pipeline(steps=[('pca', PCA(n_components=17)), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA17_SMOTE',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA17_SMOTE',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=17)), ('over', SMOTE()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA17_SMOTE',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA17_SMOTE',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA17_SMOTE',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('m', LinearDiscriminantAnalysis())])),
#  ('None_PCA17_SMOTE_Under',
#   Pipeline(steps=[('pca', PCA(n_components=17)), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Yeo_Johnson_PCA17_SMOTE_Under',
#   Pipeline(steps=[('t1', PowerTransformer()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Box_Cox_PCA17_SMOTE_Under',
#   Pipeline(steps=[('t1', MinMaxScaler(feature_range=(1, 2))),
#                   ('t2', PowerTransformer(method='box-cox')),
#                   ('pca', PCA(n_components=17)), ('over', SMOTE()),
#                   ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('MinMax_PCA17_SMOTE_Under',
#   Pipeline(steps=[('t1', MinMaxScaler()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Standardize_PCA17_SMOTE_Under',
#   Pipeline(steps=[('t1', StandardScaler()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())])),
#  ('Robust_Scaler_PCA17_SMOTE_Under',
#   Pipeline(steps=[('t1', RobustScaler()), ('pca', PCA(n_components=17)),
#                   ('over', SMOTE()), ('under', RandomUnderSampler()),
#                   ('m', LinearDiscriminantAnalysis())]))]

# %%
#Create table containing training time, Recall, F2, ROCAUC of each pipeline for logistic regression

ftwo_scorer = make_scorer(fbeta_score, beta=2)

X = full_frame.drop(columns='GreenLeaderBinary')
y = full_frame['GreenLeaderBinary']


model=LogisticRegression()
pipelines = get_mixed_pipelines(model)

spotchecks_LG = []

for name, pipeline in pipelines:
    
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=42)

    scores = sklearn.model_selection.cross_validate(pipeline, X, y, scoring = {'recall': 'recall','ftwo_scorer': make_scorer(fbeta_score, beta=2),'roc_auc':'roc_auc'}, cv=cv, n_jobs=-1)
    
    print(name, np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3))
    spotchecks_LG.append((name,np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3)))

pd.DataFrame(spotchecks_LG).to_csv('Evaluation_List_LogReg.csv')
# Out:
# None_None_None 4.795 0.04 0.048 0.798
# Yeo_Johnson_None_None 12.166 0.108 0.128 0.876
# Box_Cox_None_None 11.389 0.106 0.126 0.875
# MinMax_None_None 5.456 0.097 0.115 0.858
# Standardize_None_None 4.59 0.1 0.118 0.858
# Robust_Scaler_None_None 6.453 0.095 0.112 0.852
# None_Rand_Over_None 12.405 0.705 0.372 0.838
# Yeo_Johnson_Rand_Over_None 21.568 0.795 0.398 0.878
# Box_Cox_Rand_Over_None 20.692 0.797 0.4 0.878
# MinMax_Rand_Over_None 12.204 0.758 0.385 0.865
# Standardize_Rand_Over_None 9.69 0.759 0.392 0.867
# Robust_Scaler_Rand_Over_None 12.078 0.761 0.385 0.865
# None_Rand_Under_None 0.648 0.72 0.376 0.838
# Yeo_Johnson_Rand_Under_None 10.641 0.803 0.391 0.875
# Box_Cox_Rand_Under_None 8.135 0.804 0.393 0.874
# MinMax_Rand_Under_None 0.632 0.769 0.369 0.859
# Standardize_Rand_Under_None 0.882 0.767 0.382 0.863
# Robust_Scaler_Rand_Under_None 0.951 0.766 0.378 0.863
# None_SMOTE_None 13.231 0.651 0.353 0.81
# Yeo_Johnson_SMOTE_None 21.687 0.779 0.395 0.874
# Box_Cox_SMOTE_None 19.218 0.785 0.399 0.874
# MinMax_SMOTE_None 11.945 0.732 0.387 0.861
# Standardize_SMOTE_None 10.715 0.738 0.381 0.86
# Robust_Scaler_SMOTE_None 12.094 0.747 0.383 0.861
# None_SMOTE_Under_None 13.678 0.652 0.35 0.807
# Yeo_Johnson_SMOTE_Under_None 20.899 0.779 0.395 0.875
# Box_Cox_SMOTE_Under_None 18.896 0.784 0.399 0.874
# MinMax_SMOTE_Under_None 11.6 0.732 0.386 0.861
# Standardize_SMOTE_Under_None 10.535 0.743 0.383 0.86
# Robust_Scaler_SMOTE_Under_None 11.952 0.745 0.38 0.861
# None_PCA4_None 2.306 0.029 0.035 0.823
# Yeo_Johnson_PCA4_None 11.815 0.0 0.001 0.807
# Box_Cox_PCA4_None 9.574 0.0 0.001 0.81
# MinMax_PCA4_None 2.218 0.0 0.0 0.784
# Standardize_PCA4_None 2.741 0.014 0.018 0.801
# Robust_Scaler_PCA4_None 2.678 0.024 0.029 0.801
# None_PCA4_Rand_Over 2.573 0.675 0.36 0.834
# Yeo_Johnson_PCA4_Rand_Over 12.026 0.744 0.307 0.808
# Box_Cox_PCA4_Rand_Over 9.763 0.738 0.313 0.811
# MinMax_PCA4_Rand_Over 2.303 0.712 0.287 0.784
# Standardize_PCA4_Rand_Over 2.857 0.704 0.315 0.805
# Robust_Scaler_PCA4_Rand_Over 2.974 0.606 0.317 0.805
# None_PCA4_Rand_Under 2.034 0.673 0.358 0.833
# Yeo_Johnson_PCA4_Rand_Under 11.754 0.742 0.307 0.808
# Box_Cox_PCA4_Rand_Under 9.592 0.734 0.311 0.811
# MinMax_PCA4_Rand_Under 2.341 0.715 0.288 0.784
# Standardize_PCA4_Rand_Under 3.108 0.709 0.315 0.805
# Robust_Scaler_PCA4_Rand_Under 3.246 0.608 0.317 0.804
# None_PCA4_SMOTE 3.357 0.674 0.359 0.833
# Yeo_Johnson_PCA4_SMOTE 14.334 0.744 0.308 0.808
# Box_Cox_PCA4_SMOTE 12.971 0.735 0.312 0.811
# MinMax_PCA4_SMOTE 2.708 0.713 0.288 0.784
# Standardize_PCA4_SMOTE 2.886 0.705 0.314 0.805
# Robust_Scaler_PCA4_SMOTE 2.934 0.608 0.317 0.805
# None_PCA4_SMOTE_Under 2.623 0.676 0.359 0.833
# Yeo_Johnson_PCA4_SMOTE_Under 11.793 0.744 0.308 0.808
# Box_Cox_PCA4_SMOTE_Under 9.467 0.735 0.312 0.811
# MinMax_PCA4_SMOTE_Under 2.282 0.713 0.288 0.784
# Standardize_PCA4_SMOTE_Under 2.73 0.707 0.315 0.805
# Robust_Scaler_PCA4_SMOTE_Under 2.865 0.61 0.318 0.805
# None_PCA8_None 2.791 0.025 0.031 0.817
# Yeo_Johnson_PCA8_None 11.561 0.006 0.008 0.836
# Box_Cox_PCA8_None 9.397 0.006 0.007 0.839
# MinMax_PCA8_None 2.418 0.0 0.0 0.792
# Standardize_PCA8_None 2.811 0.03 0.037 0.83
# Robust_Scaler_PCA8_None 3.026 0.035 0.043 0.824
# None_PCA8_Rand_Over 2.962 0.681 0.358 0.833
# Yeo_Johnson_PCA8_Rand_Over 11.593 0.77 0.336 0.837
# Box_Cox_PCA8_Rand_Over 9.568 0.768 0.342 0.839
# MinMax_PCA8_Rand_Over 2.588 0.749 0.29 0.792
# Standardize_PCA8_Rand_Over 2.995 0.729 0.35 0.838
# Robust_Scaler_PCA8_Rand_Over 3.382 0.648 0.355 0.83
# None_PCA8_Rand_Under 2.187 0.686 0.36 0.834
# Yeo_Johnson_PCA8_Rand_Under 11.44 0.768 0.333 0.836
# Box_Cox_PCA8_Rand_Under 9.493 0.767 0.34 0.839
# MinMax_PCA8_Rand_Under 2.41 0.746 0.289 0.792
# Standardize_PCA8_Rand_Under 2.709 0.73 0.353 0.837
# Robust_Scaler_PCA8_Rand_Under 2.677 0.644 0.353 0.829
# None_PCA8_SMOTE 3.031 0.684 0.358 0.831
# Yeo_Johnson_PCA8_SMOTE 11.357 0.763 0.335 0.836
# Box_Cox_PCA8_SMOTE 9.413 0.764 0.342 0.839
# MinMax_PCA8_SMOTE 2.576 0.746 0.289 0.792
# Standardize_PCA8_SMOTE 2.965 0.728 0.349 0.837
# Robust_Scaler_PCA8_SMOTE 3.52 0.651 0.357 0.827
# None_PCA8_SMOTE_Under 3.042 0.685 0.358 0.831
# Yeo_Johnson_PCA8_SMOTE_Under 11.319 0.764 0.335 0.836
# Box_Cox_PCA8_SMOTE_Under 9.392 0.765 0.342 0.839
# MinMax_PCA8_SMOTE_Under 2.616 0.747 0.29 0.792
# Standardize_PCA8_SMOTE_Under 3.002 0.728 0.348 0.837
# Robust_Scaler_PCA8_SMOTE_Under 3.488 0.652 0.357 0.827
# None_PCA17_None 3.684 0.04 0.049 0.824
# Yeo_Johnson_PCA17_None 11.058 0.044 0.053 0.854
# Box_Cox_PCA17_None 10.429 0.042 0.051 0.856
# MinMax_PCA17_None 2.918 0.0 0.0 0.818
# Standardize_PCA17_None 3.151 0.047 0.057 0.84
# Robust_Scaler_PCA17_None 4.644 0.034 0.041 0.827
# None_PCA17_Rand_Over 6.175 0.702 0.372 0.841
# Yeo_Johnson_PCA17_Rand_Over 11.65 0.78 0.362 0.858
# Box_Cox_PCA17_Rand_Over 9.36 0.781 0.367 0.858
# MinMax_PCA17_Rand_Over 2.626 0.759 0.315 0.819
# Standardize_PCA17_Rand_Over 2.996 0.742 0.369 0.848
# Robust_Scaler_PCA17_Rand_Over 4.856 0.722 0.364 0.845
# None_PCA17_Rand_Under 2.019 0.707 0.379 0.842
# Yeo_Johnson_PCA17_Rand_Under 10.495 0.779 0.36 0.856
# Box_Cox_PCA17_Rand_Under 8.649 0.776 0.365 0.858
# MinMax_PCA17_Rand_Under 2.09 0.762 0.316 0.82
# Standardize_PCA17_Rand_Under 2.426 0.748 0.371 0.851
# Robust_Scaler_PCA17_Rand_Under 2.433 0.726 0.364 0.845
# None_PCA17_SMOTE 5.825 0.701 0.373 0.836
# Yeo_Johnson_PCA17_SMOTE 11.391 0.775 0.36 0.855
# Box_Cox_PCA17_SMOTE 9.745 0.778 0.365 0.857
# MinMax_PCA17_SMOTE 2.989 0.755 0.317 0.818
# Standardize_PCA17_SMOTE 3.34 0.742 0.367 0.846
# Robust_Scaler_PCA17_SMOTE 5.692 0.72 0.365 0.842
# None_PCA17_SMOTE_Under 5.607 0.701 0.37 0.837
# Yeo_Johnson_PCA17_SMOTE_Under 11.716 0.776 0.359 0.856
# Box_Cox_PCA17_SMOTE_Under 9.903 0.78 0.367 0.857
# MinMax_PCA17_SMOTE_Under 3.037 0.754 0.318 0.819
# Standardize_PCA17_SMOTE_Under 3.354 0.736 0.365 0.846
# Robust_Scaler_PCA17_SMOTE_Under 5.547 0.722 0.366 0.842

# %%
#Create table containing training time, Recall, F2, ROCAUC of each pipeline for LDA

ftwo_scorer = make_scorer(fbeta_score, beta=2)

X = full_frame.drop(columns='GreenLeaderBinary')
y = full_frame['GreenLeaderBinary']


model=LinearDiscriminantAnalysis()
pipelines = get_mixed_pipelines(model)

spotchecks_LG = []

for name, pipeline in pipelines:
    
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=42)

    scores = sklearn.model_selection.cross_validate(pipeline, X, y, scoring = {'recall': 'recall','ftwo_scorer': make_scorer(fbeta_score, beta=2),'roc_auc':'roc_auc'}, cv=cv, n_jobs=-1)
    
    print(name, np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3))
    spotchecks_LG.append((name,np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3)))

pd.DataFrame(spotchecks_LG).to_csv('Evaluation_List_LDA.csv')

# %%
#Create table containing training time, Recall, F2, ROCAUC of each pipeline for QDA

ftwo_scorer = make_scorer(fbeta_score, beta=2)

X = full_frame.drop(columns='GreenLeaderBinary')
y = full_frame['GreenLeaderBinary']


model=QuadraticDiscriminantAnalysis()
pipelines = get_mixed_pipelines(model)

spotchecks_LG = []

for name, pipeline in pipelines:
    
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=42)

    scores = sklearn.model_selection.cross_validate(pipeline, X, y, scoring = {'recall': 'recall','ftwo_scorer': make_scorer(fbeta_score, beta=2),'roc_auc':'roc_auc'}, cv=cv, n_jobs=-1)
    
    print(name, np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3))
    spotchecks_LG.append((name,np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3)))

pd.DataFrame(spotchecks_LG).to_csv('Evaluation_List_QDA.csv')

# %%
#Create table containing training time, Recall, F2, ROCAUC of each pipeline for Random Forest

ftwo_scorer = make_scorer(fbeta_score, beta=2)

X = full_frame.drop(columns='GreenLeaderBinary')
y = full_frame['GreenLeaderBinary']


model=RandomForestClassifier()
pipelines = get_mixed_pipelines(model)

spotchecks_LG = []

for name, pipeline in pipelines:
    
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=42)

    scores = sklearn.model_selection.cross_validate(pipeline, X, y, scoring = {'recall': 'recall','ftwo_scorer': make_scorer(fbeta_score, beta=2),'roc_auc':'roc_auc'}, cv=cv, n_jobs=-1)
    
    print(name, np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3))
    spotchecks_LG.append((name,np.round(np.mean(scores['fit_time']),3),np.round(np.mean(scores['test_recall']),3),np.round(np.mean(scores['test_ftwo_scorer']),3),np.round(np.mean(scores['test_roc_auc']),3)))

pd.DataFrame(spotchecks_LG).to_csv('Evaluation_List_RandomForest.csv')

# %%
# from the above tables, the highest performing pipelines for each metric were determined.
# in order to better understand their qualities, averaged confusion matrices are calculated
# the calculation of metrics was done using 10-fold cross validation
# here, 10 confusion matrices calculated based on the sub-groups from cross validation are averaged

#get y and X
y=np.array(full_frame['GreenLeaderBinary'])
X=np.array(full_frame.drop(columns=['GreenLeaderBinary']))

#create empty list to save confusion matrices
conf_matrix_list_of_arrays = []

#set cross validation parameters
kf=RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=42)


#Highest Recall
#pipeline= imblearn.pipeline.Pipeline(steps=[
#                  ('under', RandomUnderSampler()),
#                  ('m', QuadraticDiscriminantAnalysis())])


#Highest F2 Score
#pipeline= imblearn.pipeline.Pipeline(steps=[('t1', RobustScaler()), ('over', SMOTE()),
#                  ('under', RandomUnderSampler()),
#                  ('m', QuadraticDiscriminantAnalysis())])

        
#highest ROC AUC score        
pipeline= imblearn.pipeline.Pipeline(steps=[('t1', MinMaxScaler()),
                  ('over', SMOTE()),
                  ('m', RandomForestClassifier())])

        
        
#use groups of observations determined by cross validation function        
for train_index, test_index in kf.split(X,y):
    
    #get y and X of subsample
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    #fit model and calculate confusion matrix for one of the 10 cases
    pipeline.fit(X_train, y_train)
    conf_matrix = confusion_matrix(y_test, pipeline.predict(X_test))
    
    #save confusion matrices in list
    conf_matrix_list_of_arrays.append(conf_matrix)
    
#return averaged and rounded confusion matrix
np.round(np.mean(conf_matrix_list_of_arrays,axis=0))
# Out:
# array([[6252.,   62.],
#        [ 177.,   61.]])

# %% [markdown]
# # F2, recall, ROCAUC metric leaders confusion matrices

# %%
#QDA for best F2
np.round(np.mean(conf_matrix_list_of_arrays,axis=0))
# Out:
# array([[5369.,  945.],
#        [  76.,  162.]])

# %%
#QDA best for recall
np.round(np.mean(conf_matrix_list_of_arrays,axis=0))
# Out:
# array([[2900., 3414.],
#        [  46.,  192.]])

# %%
#Random Forest for best ROCAUC
np.round(np.mean(conf_matrix_list_of_arrays,axis=0))
# Out:
# array([[6252.,   62.],
#        [ 177.,   61.]])
